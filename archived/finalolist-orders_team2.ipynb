# %% [markdown]
# # Imports and Configurations

# %%
# Import libraries
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import squarify
import seaborn as sns

# To perform KMeans clustering 
from sklearn.cluster import KMeans
# t-SNE with scikit-learn
from sklearn.manifold import TSNE

# %% [markdown]
# # Functions

# %% [markdown]
# # Joining dataset

# %%
#final dataframe
df = pd.DataFrame()

# %%
# read all datasets

# orders dataset
orders = pd.read_csv('data/olist_orders_dataset.csv')

# order items dataset
items = pd.read_csv('data/olist_order_items_dataset.csv')

# sellers dataset
sellers = pd.read_csv('data/olist_sellers_dataset.csv')

# sellers dataset
customers = pd.read_csv('data/olist_customers_dataset.csv')

# reviews dataset
reviews = pd.read_csv('data/olist_order_reviews_dataset.csv')

# products dataset
products = pd.read_csv('data/olist_products_dataset.csv')

# sellers dataset
payments = pd.read_csv('data/olist_order_payments_dataset.csv')

# categories dataset
categories = pd.read_csv('data/product_category_name_translation.csv')

# %%
df = orders

df = df.merge(customers, on='customer_id', how='left')
df = df.merge(payments, on='order_id', how='left')
df = df.merge(reviews, on='order_id', how='left')

df = df.merge(items, on='order_id', how='left')
df = df.merge(sellers, on='seller_id', how='left')
df = df.merge(products, on='product_id', how='left')
df = df.merge(categories, on='product_category_name', how='left')

df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 3           2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 4           2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... seller_state  product_category_name  \
# 0                      3149  ...           SP  utilidades_domesticas
# 1                      3149  ...           SP  utilidades_domesticas
# 2                      3149  ...           SP  utilidades_domesticas
# 3                     47813  ...           SP             perfumaria
# 4                     75265  ...           SP             automotivo
#
#    product_name_lenght product_description_lenght  product_photos_qty  \
# 0                 40.0                      268.0                 4.0
# 1                 40.0                      268.0                 4.0
# 2                 40.0                      268.0                 4.0
# 3                 29.0                      178.0                 1.0
# 4                 46.0                      232.0                 1.0
#
#    product_weight_g product_length_cm  product_height_cm product_width_cm  \
# 0             500.0              19.0                8.0             13.0
# 1             500.0              19.0                8.0             13.0
# 2             500.0              19.0                8.0             13.0
# 3             400.0              19.0               13.0             19.0
# 4             420.0              24.0               19.0             21.0
#
#   product_category_name_english
# 0                    housewares
# 1                    housewares
# 2                    housewares
# 3                     perfumery
# 4                          auto
#
# [5 rows x 40 columns]

# %%
df.to_csv('data/merged_dataset.csv')

# %% [markdown]
# # Cleaning data

# %%
# change datatime
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])
df["order_delivered_carrier_date"] = pd.to_datetime(df["order_delivered_carrier_date"])
df["order_delivered_customer_date"] = pd.to_datetime(df["order_delivered_customer_date"])
df["order_estimated_delivery_date"] = pd.to_datetime(df["order_estimated_delivery_date"])
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                        object
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# payment_sequential                      float64
# payment_type                             object
# payment_installments                    float64
# payment_value                           float64
# review_id                                object
# review_score                              int64
# review_comment_title                     object
# review_comment_message                   object
# review_creation_date                     object
# review_answer_timestamp                  object
# order_item_id                           float64
# product_id                               object
# seller_id                                object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# seller_zip_code_prefix                  float64
# seller_city                              object
# seller_state                             object
# product_category_name                    object
# product_name_lenght                     float64
# product_description_lenght              float64
# product_photos_qty                      float64
# product_weight_g                        float64
# product_length_cm                       float64
# product_height_cm                       float64
# product_width_cm                        float64
# product_category_name_english            object
# dtype: object

# %%
# need to fix missing data 610 is the same entry but missing description. 2 items also missing (1 competely missing all except ID
#other one is just missing weight, lenght, height, width) Dtypes changed from float64 to object as a result of replacing NA
df["product_category_name"].fillna("None", inplace = True)
df["product_name_lenght"].fillna("None", inplace = True)
df["product_description_lenght"].fillna("None", inplace = True)
df["product_photos_qty"].fillna("None", inplace = True)
df["product_weight_g"].fillna("0", inplace = True)
df["product_length_cm"].fillna("0", inplace = True)
df["product_height_cm"].fillna("0", inplace = True)
df["product_width_cm"].fillna("0", inplace = True)

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2018-08-13  af07308b275d755c9edb36a90c618231
# 4                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... seller_state  product_category_name  \
# 0                      3149  ...           SP  utilidades_domesticas
# 1                      3149  ...           SP  utilidades_domesticas
# 2                      3149  ...           SP  utilidades_domesticas
# 3                     47813  ...           SP             perfumaria
# 4                     75265  ...           SP             automotivo
#
#    product_name_lenght product_description_lenght  product_photos_qty  \
# 0                   40                        268                   4
# 1                   40                        268                   4
# 2                   40                        268                   4
# 3                   29                        178                   1
# 4                   46                        232                   1
#
#    product_weight_g product_length_cm  product_height_cm product_width_cm  \
# 0               500                19                  8               13
# 1               500                19                  8               13
# 2               500                19                  8               13
# 3               400                19                 13               19
# 4               420                24                 19               21
#
#   product_category_name_english
# 0                    housewares
# 1                    housewares
# 2                    housewares
# 3                     perfumery
# 4                          auto
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119151 non-null  object
#  1   customer_id                    119151 non-null  object
#  2   order_status                   119151 non-null  object
#  3   order_purchase_timestamp       119151 non-null  datetime64[ns]
#  4   order_approved_at              118974 non-null  object
#  5   order_delivered_carrier_date   117065 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115730 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  119151 non-null  datetime64[ns]
#  8   customer_unique_id             119151 non-null  object
#  9   customer_zip_code_prefix       119151 non-null  int64
#  10  customer_city                  119151 non-null  object
#  11  customer_state                 119151 non-null  object
#  12  payment_sequential             119148 non-null  float64
#  13  payment_type                   119148 non-null  object
#  14  payment_installments           119148 non-null  float64
#  15  payment_value                  119148 non-null  float64
#  16  review_id                      119151 non-null  object
#  17  review_score                   119151 non-null  int64
#  18  review_comment_title           14189 non-null   object
#  19  review_comment_message         51250 non-null   object
#  20  review_creation_date           119151 non-null  object
#  21  review_answer_timestamp        119151 non-null  object
#  22  order_item_id                  118318 non-null  float64
#  23  product_id                     118318 non-null  object
#  24  seller_id                      118318 non-null  object
#  25  shipping_limit_date            118318 non-null  object
#  26  price                          118318 non-null  float64
#  27  freight_value                  118318 non-null  float64
#  28  seller_zip_code_prefix         118318 non-null  float64
#  29  seller_city                    118318 non-null  object
#  30  seller_state                   118318 non-null  object
#  31  product_category_name          119151 non-null  object
#  32  product_name_lenght            119151 non-null  object
#  33  product_description_lenght     119151 non-null  object
#  34  product_photos_qty             119151 non-null  object
#  35  product_weight_g               119151 non-null  object
#  36  product_length_cm              119151 non-null  object
#  37  product_height_cm              119151 non-null  object
#  38  product_width_cm               119151 non-null  object
#  39  product_category_name_english  116584 non-null  object
# dtypes: datetime64[ns](4), float64(7), int64(2), object(27)
# memory usage: 37.3+ MB

# %% [markdown]
# # RFM

# %%
# --Group data by customerID--
# Create TotalSum column for online dataset
#df['TotalSum'] = df['price'] * online['UnitPrice']
# Create snapshot date
snapshot_date = df['order_purchase_timestamp'].max() + datetime.timedelta(days=1)
print(snapshot_date)
# Grouping by CustomerID
data_process = df.groupby(['customer_id']).agg({
        'order_purchase_timestamp': lambda x: (snapshot_date - x.max()).days,
        'order_id': 'count',
        'price': 'sum'})
# Rename the columns 
data_process.rename(columns={'order_purchase_timestamp': 'Recency',
                         'order_id': 'Frequency',
                         'price': 'MonetaryValue'}, inplace=True)
# Out:
# 2018-10-18 17:30:18

# %%
# Print top 5 rows and shape of dataframe
print(data_process.head())
print('{:,} rows; {:,} columns'
      .format(data_process.shape[0], data_process.shape[1]))
# Out:
#                                   Recency  Frequency  MonetaryValue
# customer_id
# 00012a2ce6f8dcda20d059ce98491703      338          1          89.80
# 000161a058600d5901f007fab4c27140      459          1          54.90
# 0001fd6190edaaf884bcaf3d49edf079      597          1         179.99
# 0002414f95344307404f0ace7a26f1d5      428          1         149.90
# 000379cdec625522490c315e70c7a9fb      199          1          93.00
# 99,441 rows; 3 columns

# %% [markdown]
# ## RFM visulization

# %%
# Plot RFM distributions
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(data_process['Recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(data_process['Frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(data_process['MonetaryValue'])
# Show the plot
plt.show()
# Out:
# C:\Users\musta\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
c1 = data_process['Frequency'].unique()
print (c1)
# Out:
# [ 1  4  2  3  6  7  5  8 10 12 11 15 38  9 16 20 63 24 13 21 14 26 29 22
#  19]

# %%
# https://towardsdatascience.com/recency-frequency-monetary-model-with-python-and-how-sephora-uses-it-to-optimize-their-google-d6a0707c5f17

# %%
data_process.head()
# Out:
#                                   Recency  Frequency  MonetaryValue
# customer_id
# 00012a2ce6f8dcda20d059ce98491703      338          1          89.80
# 000161a058600d5901f007fab4c27140      459          1          54.90
# 0001fd6190edaaf884bcaf3d49edf079      597          1         179.99
# 0002414f95344307404f0ace7a26f1d5      428          1         149.90
# 000379cdec625522490c315e70c7a9fb      199          1          93.00

# %%
RFM_process = data_process

# %%
RFM_K3 = data_process.reset_index()
RFM_K3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    99441 non-null  object
#  1   Recency        99441 non-null  int64
#  2   Frequency      99441 non-null  int64
#  3   MonetaryValue  99441 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# # Calulate R F M score

# %%
# --Calculate R and F groups--
# Create labels for Recency and Frequency
r_labels = range(4, 0, -1); f_labels = range(1, 5)
# Assign these labels to 4 equal percentile groups 
r_groups = pd.qcut(data_process['Recency'], q=4, labels=r_labels)
# Assign these labels to 4 equal percentile groups 
f_groups = pd.qcut(data_process['Frequency'].rank(method='first'), q=4, labels=f_labels)
# Create new columns R and F 
data_process = data_process.assign(R = r_groups.values, F = f_groups.values)
data_process.head()
# Out:
#                                   Recency  Frequency  MonetaryValue  R  F
# customer_id
# 00012a2ce6f8dcda20d059ce98491703      338          1          89.80  2  1
# 000161a058600d5901f007fab4c27140      459          1          54.90  1  1
# 0001fd6190edaaf884bcaf3d49edf079      597          1         179.99  1  1
# 0002414f95344307404f0ace7a26f1d5      428          1         149.90  1  1
# 000379cdec625522490c315e70c7a9fb      199          1          93.00  3  1

# %%
# Create labels for MonetaryValue
m_labels = range(1, 5)
# Assign these labels to three equal percentile groups 
m_groups = pd.qcut(data_process['MonetaryValue'], q=4, labels=m_labels)
# Create new column M
data_process = data_process.assign(M = m_groups.values)

# %%
# Concat RFM quartile values to create RFM Segments
def join_rfm(x): return str(x['R']) + str(x['F']) + str(x['M'])
data_process['RFM_Segment_Concat'] = data_process.apply(join_rfm, axis=1)
rfm = data_process
rfm.head()
# Out:
#                                   Recency  Frequency  MonetaryValue  R  F  M  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703      338          1          89.80  2  1  3
# 000161a058600d5901f007fab4c27140      459          1          54.90  1  1  2
# 0001fd6190edaaf884bcaf3d49edf079      597          1         179.99  1  1  4
# 0002414f95344307404f0ace7a26f1d5      428          1         149.90  1  1  3
# 000379cdec625522490c315e70c7a9fb      199          1          93.00  3  1  3
#
#                                  RFM_Segment_Concat
# customer_id
# 00012a2ce6f8dcda20d059ce98491703                213
# 000161a058600d5901f007fab4c27140                112
# 0001fd6190edaaf884bcaf3d49edf079                114
# 0002414f95344307404f0ace7a26f1d5                113
# 000379cdec625522490c315e70c7a9fb                313

# %%
# Count num of unique segments
rfm_count_unique = rfm.groupby('RFM_Segment_Concat')['RFM_Segment_Concat'].nunique()
print(rfm_count_unique.sum())
# Out:
# 64

# %%
# Calculate RFM_Score
rfm['RFM_Score'] = rfm[['R','F','M']].sum(axis=1)
print(rfm['RFM_Score'].head())
# Out:
# customer_id
# 00012a2ce6f8dcda20d059ce98491703    6.0
# 000161a058600d5901f007fab4c27140    4.0
# 0001fd6190edaaf884bcaf3d49edf079    6.0
# 0002414f95344307404f0ace7a26f1d5    5.0
# 000379cdec625522490c315e70c7a9fb    7.0
# Name: RFM_Score, dtype: float64

# %%
# Define rfm_level function
def rfm_level(df):
    if df['RFM_Score'] >= 9:
        return 'Can\'t Loose Them'
    elif ((df['RFM_Score'] >= 8) and (df['RFM_Score'] < 9)):
        return 'Champions'
    elif ((df['RFM_Score'] >= 7) and (df['RFM_Score'] < 8)):
        return 'Loyal'
    elif ((df['RFM_Score'] >= 6) and (df['RFM_Score'] < 7)):
        return 'Potential'
    elif ((df['RFM_Score'] >= 5) and (df['RFM_Score'] < 6)):
        return 'Promising'
    elif ((df['RFM_Score'] >= 4) and (df['RFM_Score'] < 5)):
        return 'Needs Attention'
    else:
        return 'Require Activation'
# Create a new variable RFM_Level
rfm['RFM_Level'] = rfm.apply(rfm_level, axis=1)
# Print the header with top 5 rows to the console
rfm.head()
# Out:
#                                   Recency  Frequency  MonetaryValue  R  F  M  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703      338          1          89.80  2  1  3
# 000161a058600d5901f007fab4c27140      459          1          54.90  1  1  2
# 0001fd6190edaaf884bcaf3d49edf079      597          1         179.99  1  1  4
# 0002414f95344307404f0ace7a26f1d5      428          1         149.90  1  1  3
# 000379cdec625522490c315e70c7a9fb      199          1          93.00  3  1  3
#
#                                  RFM_Segment_Concat  RFM_Score  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703                213        6.0
# 000161a058600d5901f007fab4c27140                112        4.0
# 0001fd6190edaaf884bcaf3d49edf079                114        6.0
# 0002414f95344307404f0ace7a26f1d5                113        5.0
# 000379cdec625522490c315e70c7a9fb                313        7.0
#
#                                         RFM_Level
# customer_id
# 00012a2ce6f8dcda20d059ce98491703        Potential
# 000161a058600d5901f007fab4c27140  Needs Attention
# 0001fd6190edaaf884bcaf3d49edf079        Potential
# 0002414f95344307404f0ace7a26f1d5        Promising
# 000379cdec625522490c315e70c7a9fb            Loyal

# %%
rfm_extract = rfm.reset_index()
rfm_extract.to_excel('RFM ranking result.xlsx', index = False)

# %%
# Calculate average values for each RFM_Level, and return a size of each segment 
rfm_level_agg = rfm.groupby('RFM_Level').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'MonetaryValue': ['mean', 'count']
}).round(1)
# Print the aggregated dataset
print(rfm_level_agg)
# Out:
#                    Recency Frequency MonetaryValue
#                       mean      mean          mean  count
# RFM_Level
# Can't Loose Them     205.4       1.5         242.6  31822
# Champions            262.2       1.1         141.5  17553
# Loyal                301.0       1.1         109.2  17937
# Needs Attention      446.3       1.0          39.2   5008
# Potential            346.2       1.0          87.0  15611
# Promising            396.1       1.0          52.4   9804
# Require Activation   509.4       1.0          26.7   1706

# %%
rfm_level_agg.columns = rfm_level_agg.columns.droplevel()
rfm_level_agg.columns = ['RecencyMean','FrequencyMean','MonetaryMean', 'Count']
#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 9)
squarify.plot(sizes=rfm_level_agg['Count'], 
              label=['Can\'t Loose Them',
                     'Champions',
                     'Loyal',
                     'Needs Attention',
                     'Potential', 
                     'Promising', 
                     'Require Activation'], alpha=.6 )
plt.title("RFM Segments",fontsize=18,fontweight="bold")
plt.axis('off')
plt.show()

# %% [markdown]
# # K_mean

# %% [markdown]
# ## Outlier treatment

# %%
RFM_process = RFM_process.reset_index()

# %%
RFM_process.head()
# Out:
#                         customer_id  Recency  Frequency  MonetaryValue
# 0  00012a2ce6f8dcda20d059ce98491703      338          1          89.80
# 1  000161a058600d5901f007fab4c27140      459          1          54.90
# 2  0001fd6190edaaf884bcaf3d49edf079      597          1         179.99
# 3  0002414f95344307404f0ace7a26f1d5      428          1         149.90
# 4  000379cdec625522490c315e70c7a9fb      199          1          93.00

# %%
# outlier treatment for MonetaryValue
plt.boxplot(RFM_process.MonetaryValue)
Q1 = RFM_process.MonetaryValue.quantile(0.25)
Q3 = RFM_process.MonetaryValue.quantile(0.75)
IQR = Q3 - Q1
RFM_process = RFM_process[(RFM_process.MonetaryValue >= (Q1 - 1.5*IQR)) & (RFM_process.MonetaryValue <= (Q3 + 1.5*IQR))]

# %%
# outlier treatment for Frequency
plt.boxplot(RFM_process.Frequency)
Q1 = RFM_process.Frequency.quantile(0.25)
Q3 = RFM_process.Frequency.quantile(0.75)
IQR = Q3 - Q1
RFM_process = RFM_process[(RFM_process.Frequency >= (Q1 - 1.5*IQR)) & (RFM_process.Frequency <= (Q3 + 1.5*IQR))]

# %%
# outlier treatment for Recency
plt.boxplot(RFM_process.Recency)
Q1 = RFM_process.Recency.quantile(0.25)
Q3 = RFM_process.Recency.quantile(0.75)
IQR = Q3 - Q1
RFM_process = RFM_process[(RFM_process.Recency >= (Q1 - 1.5*IQR)) & (RFM_process.Recency <= (Q3 + 1.5*IQR))]

# %%
RFM_process.head(20)
# Out:
#                          customer_id  Recency  Frequency  MonetaryValue
# 0   00012a2ce6f8dcda20d059ce98491703      338          1          89.80
# 1   000161a058600d5901f007fab4c27140      459          1          54.90
# 2   0001fd6190edaaf884bcaf3d49edf079      597          1         179.99
# 3   0002414f95344307404f0ace7a26f1d5      428          1         149.90
# 4   000379cdec625522490c315e70c7a9fb      199          1          93.00
# 5   0004164d20a9e969af783496f3408652      554          1          59.99
# 6   000419c5494106c306a97b5635748086      229          1          34.30
# 7   00046a560d407e99b969756e0b10f282      304          1         120.90
# 8   00050bf6e01e69d5c0fd612f1bcfb69c      396          1          69.99
# 9   000598caf2ef4117407665ac33275130       68          1        1107.00
# 10  0005aefbb696d34b3424dccd0a0e9fd0      120          1         134.90
# 11  00062b33cb9f6fe976afdcff967ea74d      581          1          47.99
# 12  00066ccbe787a588c52bd5ff404590e3      254          4         199.60
# 13  00072d033fe2e59061ae5c3aff1a2be5      412          1          89.90
# 14  0009a69b72033b2d0ec8c69fc70ef768      538          1         159.90
# 15  000bf8121c3412d3057d32371c5d3395      372          2          30.00
# 16  000e943451fc2788ca6ac98a682f2f49      545          4         359.60
# 17  000f17e290c26b28549908a04cfe36c1      342          1         122.90
# 18  000fd45d6fedae68fc6676036610f879      186          1          53.99
# 19  0010068a73b7c56da5758c3f9e5c7375      554          1          29.99

# %% [markdown]
# ## Scaling the RFM data

# %%
# standardise all parameters
RFM_norm1 = RFM_process.drop(["customer_id"], axis=1)
#RFM_norm1.Recency = RFM_norm1.Recency.dt.days

from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
RFM_norm1 = standard_scaler.fit_transform(RFM_norm1)

# %%
RFM_norm1 = pd.DataFrame(RFM_norm1)
RFM_norm1.columns = ['Recency','Frequency','MonetaryValue']
RFM_norm1.head()
# Out:
#     Recency  Frequency  MonetaryValue
# 0  0.306507  -0.263896      -0.222624
# 1  1.093926  -0.263896      -0.367169
# 2  1.991974  -0.263896       0.150914
# 3  0.892190  -0.263896       0.026291
# 4 -0.598049  -0.263896      -0.209371

# %%
# Kmeans with K=5
model_clus5 = KMeans(n_clusters = 5, max_iter=50)
model_clus5.fit(RFM_norm1)
# Out:
# KMeans(max_iter=50, n_clusters=5)

# %%
# Silhouette Analysis¶
# silhouette score=p−qmax(p,q)
 
# p  is the mean distance to the points in the nearest cluster that the data point is not a part of

# q  is the mean intra-cluster distance to all the points in its own cluster.

# The value of the silhouette score range lies between -1 to 1.

# A score closer to 1 indicates that the data point is very similar to other data points in the cluster,

# A score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k).fit(RFM_norm1)
    sse_.append([k, silhouette_score(RFM_norm1, kmeans.labels_)])

# %%
plt.plot(pd.DataFrame(sse_)[0], pd.DataFrame(sse_)[1]);

# %%
RFM_norm1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Recency        99441 non-null  float64
#  1   Frequency      99441 non-null  float64
#  2   MonetaryValue  99441 non-null  float64
# dtypes: float64(3)
# memory usage: 2.3 MB

# %%
RFM_K3 = RFM_K3.drop(["customer_id"], axis=1)
kmeans_3 = KMeans(n_clusters=3).fit(RFM_K3)

# %%
RFM_K3['Cluster'] = kmeans_3.labels_
RFM_K3.head()
# Out:
#                         customer_id  Recency  Frequency  MonetaryValue  \
# 0  00012a2ce6f8dcda20d059ce98491703      338          1          89.80
# 1  000161a058600d5901f007fab4c27140      459          1          54.90
# 2  0001fd6190edaaf884bcaf3d49edf079      597          1         179.99
# 3  0002414f95344307404f0ace7a26f1d5      428          1         149.90
# 4  000379cdec625522490c315e70c7a9fb      199          1          93.00
#
#    Cluster
# 0        2
# 1        2
# 2        2
# 3        1
# 4        0

# %%
RFM_K3.to_excel('RFM ranking result-RFMK3.xlsx', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Software\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# C:\Software\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# C:\Software\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     634         try:
# --> 635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     636                                 allowZip64=self.allow_zip64)
#
# C:\Software\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: 'RFM ranking result-RFMK3.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-100-e8a65d4546fe> in <module>
# ----> 1 RFM_K3.to_excel('RFM ranking result-RFMK3.xlsx', index = False)
#
# C:\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2024             inf_rep=inf_rep,
#    2025         )
# -> 2026         formatter.write(
#    2027             excel_writer,
#    2028             sheet_name=sheet_name,
#
# C:\Software\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     740         )
#     741         if need_save:
# --> 742             writer.save()
#
# C:\Software\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     191         Save workbook to disk.
#     192         """
# --> 193         return self.book.close()
#     194
#     195     def write_cells(
#
# C:\Software\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     320                 self._store_workbook()
#     321             except IOError as e:
# --> 322                 raise FileCreateError(e)
#     323             except LargeZipFile as e:
#     324                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: 'RFM ranking result-RFMK3.xlsx'

# %%
def kmeans(normalised_df_rfm, clusters_number, original_df_rfm):
    
    kmeans = KMeans(n_clusters = clusters_number, random_state = 1)
    kmeans.fit(normalised_df_rfm)
# Extract cluster labels
    cluster_labels = kmeans.labels_
        
    # Create a cluster label column in original dataset
    df_new = original_df_rfm.assign(Cluster = cluster_labels)
    
    # Initialise TSNE
    model = TSNE(random_state=1)
    transformed = model.fit_transform(df_new.drop(["customer_id"], axis=1))
    
    # Plot t-SNE
    plt.title('Flattened Graph of {} Clusters'.format(clusters_number))
    sns.scatterplot(x=transformed[:,0], y=transformed[:,1], hue=cluster_labels, style=cluster_labels, palette="Set1")
    
    return df_new
plt.figure(figsize=(10, 10))
plt.subplot(3, 1, 1)
df_rfm_k3 = kmeans(RFM_norm1, 3, RFM_process)
plt.subplot(3, 1, 2)
df_rfm_k4 = kmeans(RFM_norm1, 4, RFM_process)
plt.subplot(3, 1, 3)
df_rfm_k5 = kmeans(RFM_norm1, 5, RFM_process)
plt.tight_layout()

# %% [markdown]
# # EDA

# %% [markdown]
# ## Customers

# %%
customers.info()
customers.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
cust = customers["customer_unique_id"].nunique()
print(cust, "unique customers")
# Out:
# 96096 unique customers

# %%
cities = customers["customer_city"].nunique()
c1 = customers.groupby('customer_city')['customer_id'].nunique().sort_values(ascending=False)
print("There are",cities,"unique cities in the dataset. The Top 10 cities based on customers_id are:")
c2 = c1.head(10)
print(c2)
print("\nTop 10 cities covers", round(c2.sum()/customers.shape[0]*100,1),"percent of all the orders.")
plt.figure(figsize=(16,8))
c2.plot(kind="bar",rot=0)
# Out:
# There are 4119 unique cities in the dataset. The Top 10 cities based on customers_id are:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: customer_id, dtype: int64
#
# Top 10 cities covers 35.2 percent of all the orders.
# <AxesSubplot:xlabel='customer_city'>

# %%
state = customers["customer_state"].nunique()
c1 = customers.groupby('customer_state')['customer_id'].nunique().sort_values(ascending=False)
print("There are",cities,"unique states in the dataset. The Top 5 states are:")
c2 = c1.head(5)
print(c2)
print("\nTop 10 states covers", round(c2.sum()/customers.shape[0]*100,1),"percent of all the orders.")
plt.figure(figsize=(16,8))
c2.plot(kind="bar",rot=0)
# Out:
# There are 4119 unique states in the dataset. The Top 5 states are:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# Name: customer_id, dtype: int64
#
# Top 10 states covers 77.2 percent of all the orders.
# <AxesSubplot:xlabel='customer_state'>

# %% [markdown]
# ## Orders

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.info()
customers.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders_mod = orders.copy()
orders_mod["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"], format='%Y-%m-%d %H:%M:%S')
orders_mod["order_delivered_carrier_date"] = pd.to_datetime(orders["order_delivered_carrier_date"], format='%Y-%m-%d %H:%M:%S')
orders_mod["order_delivered_customer_date"] = pd.to_datetime(orders["order_delivered_customer_date"], format='%Y-%m-%d %H:%M:%S')
orders_mod["order_estimated_delivery_date"] = pd.to_datetime(orders["order_estimated_delivery_date"], format='%Y-%m-%d %H:%M:%S')
orders_mod.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                        object
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
orders_mod.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13
# 2                    2018-09-04
# 3                    2017-12-15
# 4                    2018-02-26

# %%
##Viz on when purchases are made during period in dataset.
counts = orders_mod.set_index("order_purchase_timestamp").groupby(pd.Grouper(freq='D')).count()
fig = plt.figure(figsize=(16,8))
ax = fig.gca()
counts.plot(y = "order_id", use_index=True, ax=ax)
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
##Identifies orderstatus distribution
orderstatus = orders["order_status"].nunique()
o1 = orders.groupby('order_status')['customer_id'].nunique().sort_values(ascending=False)
print("There are",orderstatus,"unique order_status in the dataset.")
o2 = o1.head(8)
print(o2)
o3 = o1.head(1)
print("\nDelivered status covers", round(o3.sum()/orders.shape[0]*100,1),"percent of all the orders.")
plt.figure(figsize=(16,8))
o2.plot(kind="bar",rot=0)
# Out:
# There are 8 unique order_status in the dataset.
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: customer_id, dtype: int64
#
# Delivered status covers 97.0 percent of all the orders.
# <AxesSubplot:xlabel='order_status'>

# %% [markdown]
# ## Order Reviews

# %%
reviews.info()
reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
reviews.isnull().values.any()
# Out:
# True

# %%
# Determine how many missing data instances
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
# Address missing data - we can see that there is a review score but not necessarily a comment or a title. Should we make it "none?"
reviews["review_comment_title"].fillna("None", inplace = True)
reviews["review_comment_message"].fillna("None", inplace = True)
reviews.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# ## Items

# %%
items.info()
items.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
sellerinfo = items["seller_id"].nunique()
o1 = items.groupby('seller_id')['order_id'].nunique().sort_values(ascending=False)
print("There are",items,"unique items in the dataset.")
o2 = o1.head(10)
print(o2)

print("\nTop 10 items covers", round(o2.sum()/orders.shape[0]*100,1),"percent of all the orders.")
plt.figure(figsize=(16,8))
o2.plot(kind="bar",rot=0)
# Out:
# There are                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns] unique items in the dataset.
# seller_id
# 6560211a19b47992c3666cc44a7e94c0    1854
# 4a3ca9315b744ce9f8e9374361493884    1806
# cc419e0650a3c5ba77189a1882b7556a    1706
# 1f50f920176fa81dab994f9023523100    1404
# da8622b14eb17ae2831f4ac5b9dab84a    1314
# 955fee9216a65b617aa5c0531780ce60    1287
# 7a67c85e85bb2ce8582c35f2203ad736    1160
# ea8482cd71df3c1969d7b9473ff13abc    1146
# 4869f7a5dfa277a7dca6462dcf3b52b2    1132
# 3d871de0142ce09b7081e2b9d1733cb1    1080
# Name: order_id, dtype: int64
#
# Top 10 items covers 14.0 percent of all the orders.
# <AxesSubplot:xlabel='seller_id'>

# %% [markdown]
# ## Sellers

# %%
sellers.info()
sellers.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellerstatus = sellers["seller_id"].nunique()
o1 = sellers.groupby('seller_city')['seller_id'].nunique().sort_values(ascending=False)
print("There are",sellerstatus,"unique sellers in the dataset.")
o2 = o1.head(8)
print(o2)

print("\nTop Seller by city covers", round(o2.sum()/orders.shape[0]*100,1),"percent of all the sellers.")
plt.figure(figsize=(16,8))
o2.plot(kind="bar",rot=0)
# Out:
# There are 3095 unique sellers in the dataset.
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# Name: seller_id, dtype: int64
#
# Top Seller by city covers 1.2 percent of all the sellers.
# <AxesSubplot:xlabel='seller_city'>

# %%
sellerstatus = sellers["seller_id"].nunique()
o1 = sellers.groupby('seller_state')['seller_id'].nunique().sort_values(ascending=False)
print("There are",sellerstatus,"unique sellers in the dataset.")
o2 = o1.head(8)
print(o2)

print("\nTop Sellers by state represents", round(o2.sum()/orders.shape[0]*100,1),"percent of all the sellers.")
plt.figure(figsize=(16,8))
o2.plot(kind="bar",rot=0)
# Out:
# There are 3095 unique sellers in the dataset.
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# Name: seller_id, dtype: int64
#
# Top Sellers by state represents 3.0 percent of all the sellers.
# <AxesSubplot:xlabel='seller_state'>

# %% [markdown]
# ## Products

# %%
products.info()
products.isnull().sum()
# need to fix missing data 610 is the same entry but missing description. 2 items also missing (1 competely missing all except ID
#other one is just missing weight, lenght, height, width) Dtypes changed from float64 to object as a result of replacing NA
products["product_category_name"].fillna("None", inplace = True)
products["product_name_lenght"].fillna("None", inplace = True)
products["product_description_lenght"].fillna("None", inplace = True)
products["product_photos_qty"].fillna("None", inplace = True)
products["product_weight_g"].fillna("0", inplace = True)
products["product_length_cm"].fillna("0", inplace = True)
products["product_height_cm"].fillna("0", inplace = True)
products["product_width_cm"].fillna("0", inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
most_product=df.groupby('product_category_name_english').aggregate({'order_id':'count'}).rename(columns={'order_id':'order_count'}).sort_values(by='order_count',ascending=False).reset_index()
most_product.head()
# Out:
#   product_category_name_english  order_count
# 0                bed_bath_table        11990
# 1                 health_beauty        10033
# 2                sports_leisure         9005
# 3               furniture_decor         8833
# 4         computers_accessories         8151

# %%
### Visualising top 10 most bought product categories:
sns.barplot(x='product_category_name_english',y='order_count',data=most_product[:10],color="green")
plt.xlabel("Product Category")
plt.ylabel("Number of orders")
plt.title("Most bought product categories")
plt.xticks(rotation='vertical')
plt.show()

# %%
prodcat= df["product_id"].nunique()
o1 = df.groupby('product_category_name_english')['product_id'].nunique().sort_values(ascending=False)
print("There are",prodcat,"unique products in the dataset.")
o2 = o1.head(10)
print(o2)

print("\nTop 10 Products by category represent", round(o2.sum()/orders.shape[0]*100,1),"percent of all the products.")
plt.figure(figsize=(16,8))
o2.plot(kind="bar",rot=0)
# Out:
# There are 32951 unique products in the dataset.
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64
#
# Top 10 Products by category represent 20.9 percent of all the products.
# <AxesSubplot:xlabel='product_category_name_english'>

# %% [markdown]
# ## Payment

# %%
payments.info()
payments.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# ## Categories

# %%
categories.info()
categories.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
# we are going to work with only reviews dataset
reviews = reviews.dropna()
reviews.head(100)

reviews_only = reviews[reviews['review_score'] == 1]
reviews_only = reviews_only['review_comment_message']
# replace numbers of words
reviews_only = reviews_only.apply(lambda t: re.sub(r"(\d+)", lambda x: num2words(int(x.group(0))), t))
# replace special characters
reviews_only = reviews_only.apply(lambda t: re.sub('[^A-zÀ-ú\s]/gi', ' ', t))
# make all letters in a lower case
reviews_only = reviews_only.apply(lambda t: t.lower())

# tokenize text and remove stop words
tokenized_reviews = reviews_only.apply(lambda t: word_tokenize(t))
tokenized_reviews = tokenized_reviews.apply(lambda t: remove_stop_words(t))

# spell check and stemming
tokenized_reviews = tokenized_reviews.apply(lambda t: spell_and_stem_words(t))

tokenized_reviews.head(100)

reviews_text = tokenized_reviews.apply(lambda t: " ".join(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-ccd29d75d11e> in <module>
#       6 reviews_only = reviews_only['review_comment_message']
#       7 # replace numbers of words
# ----> 8 reviews_only = reviews_only.apply(lambda t: re.sub(r"(\d+)", lambda x: num2words(int(x.group(0))), t))
#       9 # replace special characters
#      10 reviews_only = reviews_only.apply(lambda t: re.sub('[^A-zÀ-ú\s]/gi', ' ', t))
#
# C:\Software\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-97-ccd29d75d11e> in <lambda>(t)
#       6 reviews_only = reviews_only['review_comment_message']
#       7 # replace numbers of words
# ----> 8 reviews_only = reviews_only.apply(lambda t: re.sub(r"(\d+)", lambda x: num2words(int(x.group(0))), t))
#       9 # replace special characters
#      10 reviews_only = reviews_only.apply(lambda t: re.sub('[^A-zÀ-ú\s]/gi', ' ', t))
#
# NameError: name 're' is not defined

# %%
# feature matrix
# creating the feature matrix
matrix = CountVectorizer(max_features=1000, ngram_range=(2, 4))
X = matrix.fit_transform(reviews_text).toarray()
matrix.vocabulary_
#
# Out:
# {'falt one': 335,
#  'one produt': 556,
#  'receb one': 787,
#  'vei quebr': 978,
#  'entreg que': 312,
#  'ate agor': 70,
#  'agor receb': 7,
#  'minh compr': 447,
#  'compr dia': 133,
#  'sab que': 823,
#  'que acontec': 730,
#  'vai ser': 955,
#  'sab que acontec': 824,
#  'boa noit': 96,
#  'zer real': 999,
#  'um produt': 942,
#  'produt defeit': 641,
#  'até agor': 77,
#  'solicit troc': 852,
#  'produt ja': 660,
#  'total satisfeit': 902,
#  'aind receb': 28,
#  'receb produt': 792,
#  'aind receb produt': 29,
#  'compr tão': 162,
#  'tão produt': 930,
#  'produt so': 691,
#  'compr tão produt': 163,
#  'devoluç produt': 202,
#  'produt baix': 629,
#  'baix qual': 92,
#  'produt baix qual': 630,
#  'descr produt': 193,
#  'produt err': 650,
#  'produt ped': 678,
#  'ped cancel': 585,
#  'fifteen dia': 345,
#  'dia aind': 205,
#  'aind não': 24,
#  'não obtiv': 517,
#  'obtiv respost': 538,
#  'não obtiv respost': 518,
#  'efet compr': 253,
#  'compr pag': 150,
#  'pag dua': 568,
#  'dua unidad': 251,
#  'unidad receb': 951,
#  'receb apen': 765,
#  'unidad aguard': 949,
#  'unidad receb apen': 952,
#  'tão unidad': 936,
#  'unidad produt': 950,
#  'produt vei': 702,
#  'tão unidad produt': 937,
#  'mesm assim': 434,
#  'loj envi': 411,
#  'envi produt': 323,
#  'produt quer': 686,
#  'quer estorv': 749,
#  'meu cart': 437,
#  'cart crédit': 109,
#  'apen one': 57,
#  'receb aind': 764,
#  'poi ped': 601,
#  'doi perfum': 246,
#  'receb apen one': 766,
#  'produt cheg': 632,
#  'bem ant': 93,
#  'ant praz': 54,
#  'com defeit': 127,
#  'realiz troc': 762,
#  'troc vit': 914,
#  'não consegu': 500,
#  'bem ant praz': 94,
#  'entr contat': 266,
#  'contat lannist': 176,
#  'ele fal': 260,
#  'pra sab': 608,
#  'entr contat lannist': 268,
#  'poss avali': 607,
#  'que receb': 739,
#  'vei difer': 970,
#  'difer anunci': 219,
#  'reembols val': 812,
#  'val pag': 958,
#  'produt vei difer': 707,
#  'not fiscal': 488,
#  'apen quer': 59,
#  'outr marc': 561,
#  'resolv problem': 814,
#  'péss rend': 717,
#  'loj lannist': 412,
#  'uma seman': 947,
#  'val produt': 960,
#  'produt entreg': 647,
#  'agor nad': 4,
#  'receb produt err': 798,
#  'até agor nad': 78,
#  'mal feit': 420,
#  'compr produt': 152,
#  'produt est': 651,
#  'defeit não': 190,
#  'não consig': 501,
#  'sempr compr': 828,
#  'produt não': 669,
#  'não cheg': 495,
#  'cheg agor': 111,
#  'produt não cheg': 670,
#  'produt aind': 623,
#  'aind cheg': 21,
#  'quer sab': 757,
#  'receb produt aind': 793,
#  'produt aind cheg': 624,
#  'inferi que': 388,
#  'me entreg': 430,
#  'entreg outr': 306,
#  'faz troc': 344,
#  'troc não': 909,
#  'consig fal': 172,
#  'não consig fal': 503,
#  'compr jour': 141,
#  'jour produt': 401,
#  'só receb': 858,
#  'receb tre': 806,
#  'one hundred': 546,
#  'de one': 188,
#  'one gineta': 544,
#  'gineta tin': 366,
#  'one gineta tin': 545,
#  'compr sim': 157,
#  'praz entreg': 609,
#  'entreg ate': 281,
#  'ate hoj': 73,
#  'tent entr': 866,
#  'uma soluç': 948,
#  'tent entr contat': 867,
#  'moment nad': 449,
#  'pod ser': 599,
#  'ser feit': 833,
#  'nad aind': 461,
#  'produt mesm': 665,
#  'vei santific': 979,
#  'com problem': 128,
#  'err não': 325,
#  'vei outr': 974,
#  'ninguém respond': 479,
#  'ninguém ritorn': 480,
#  'mand err': 421,
#  'não respond': 531,
#  'foi entreg': 354,
#  'não entreg': 508,
#  'produt não entreg': 671,
#  'fiz ped': 352,
#  'tirte jour': 892,
#  'jour thousand': 402,
#  'thousand and': 878,
#  'and eighteen': 35,
#  'mesm dia': 435,
#  'produt até': 628,
#  'até hoj': 83,
#  'sim thousand': 842,
#  'de mê': 187,
#  'cheg produt': 124,
#  'minh resid': 448,
#  'vou ter': 998,
#  'jour thousand and': 403,
#  'thousand and eighteen': 879,
#  'sim thousand and': 843,
#  'jour thousand and eighteen': 404,
#  'sim thousand and eighteen': 844,
#  'pass praz': 583,
#  'entreg aind': 273,
#  'pass praz entreg': 584,
#  'entreg aind receb': 274,
#  'muit temp': 456,
#  'compr doi': 134,
#  'cheg apen': 114,
#  'aind obtiv': 26,
#  'obtiv nenhum': 537,
#  'nenhum respost': 464,
#  'produt func': 659,
#  'produt orig': 674,
#  'ped cheg': 586,
#  'dess vez': 195,
#  'produt envi': 649,
#  'vei total': 981,
#  'total err': 901,
#  'quer troc': 759,
#  'vei total err': 982,
#  'vei one': 973,
#  'esper respost': 328,
#  'ped vei': 597,
#  'vei err': 971,
#  'produt falsific': 655,
#  'ach produt': 2,
#  'não recom': 529,
#  'não sancion': 532,
#  'cor err': 181,
#  'send não': 830,
#  'produt difer': 644,
#  'difer que': 225,
#  'produt receb': 687,
#  'receb produt difer': 797,
#  'produt difer que': 645,
#  'doi pend': 245,
#  'receb soment': 804,
#  'tão relógi': 931,
#  'só cheg': 856,
#  'one mand': 551,
#  'mand mens': 423,
#  'agor tiv': 9,
#  'tiv respost': 897,
#  'one mand mens': 552,
#  'até agor tiv': 81,
#  'entreg apen': 277,
#  'apen tão': 61,
#  'entreg apen tão': 279,
#  'compr tre': 160,
#  'tão luminár': 924,
#  'for entreg': 360,
#  'ate agor nad': 71,
#  'pag não': 570,
#  'não receb': 526,
#  'pag não receb': 571,
#  'não receb produt': 528,
#  'pag não receb produt': 572,
#  'me envi': 431,
#  'propagand engan': 713,
#  'que hav': 734,
#  'tão thousand': 934,
#  'troc produt': 912,
#  'tão thousand and': 935,
#  'não compr': 499,
#  'compr nov': 148,
#  'entreg praz': 309,
#  'cheg tod': 126,
#  'entreg produt': 310,
#  'produt compr': 635,
#  'efetu troc': 254,
#  'realiz compr': 760,
#  'compr não': 149,
#  'receb meu': 780,
#  'meu produt': 441,
#  'receb meu produt': 781,
#  'simples entreg': 845,
#  'cancel compr': 105,
#  'compr foi': 139,
#  'receb nenhum': 783,
#  'produt vei err': 708,
#  'compr um': 164,
#  'ser entreg': 831,
#  'entreg ant': 275,
#  'vei cor': 965,
#  'err compr': 324,
#  'entreg ant praz': 276,
#  'produt vei cor': 705,
#  'vei cor err': 966,
#  'cheg ant': 113,
#  'praz estipul': 610,
#  'não vei': 536,
#  'vei conform': 964,
#  'conform anunci': 167,
#  'vei falt': 972,
#  'apen receb': 60,
#  'receb jour': 777,
#  'ninguém atend': 476,
#  'produt vei falt': 709,
#  'produt poi': 679,
#  'prim vez': 620,
#  'vez compr': 991,
#  'compr vit': 165,
#  'quer produt': 755,
#  'compr jog': 140,
#  'me mand': 432,
#  'mand tão': 427,
#  'respond mail': 817,
#  'não quer': 525,
#  'val compr': 957,
#  'me mand tão': 433,
#  'total difer': 900,
#  'no estoqu': 485,
#  'vit lannist': 994,
#  'solicit cancel': 849,
#  'pag fret': 569,
#  'no correi': 483,
#  'moment receb': 451,
#  'já pag': 405,
#  'sid entreg': 836,
#  'receb nad': 782,
#  'aguard respost': 16,
#  'não receb nad': 527,
#  'one dia': 543,
#  'até há': 85,
#  'produt foi': 657,
#  'tão dia': 918,
#  'tent contat': 863,
#  'compr dua': 136,
#  'máx entreg': 458,
#  'entreg dia': 287,
#  'dia tento': 214,
#  'até pres': 89,
#  'pres dat': 614,
#  'dat receb': 186,
#  'entreg dia tento': 288,
#  'pres dat receb': 615,
#  'respeit client': 815,
#  'tent dia': 865,
#  'envi apen': 319,
#  'foi envi': 356,
#  'est funcion': 331,
#  'precis faz': 612,
#  'tão tem': 933,
#  'difer produt': 224,
#  'difer fat': 221,
#  'fat produt': 341,
#  'produt vit': 712,
#  'além diss': 32,
#  'parc targaryen': 581,
#  'entreg muit': 300,
#  'entreg quer': 313,
#  'quer dinh': 747,
#  'dinh volt': 233,
#  'quer dinh volt': 748,
#  'hor compr': 375,
#  'compr mesm': 145,
#  'receb entreg': 776,
#  'so entreg': 847,
#  'porém foi': 604,
#  'compr relógi': 156,
#  'complet difer': 129,
#  'difer imag': 222,
#  'dev faz': 198,
#  'produt meu': 666,
#  'meu dinh': 438,
#  'meu dinh volt': 439,
#  'gost produt': 368,
#  'minh cidad': 446,
#  'bom dia': 101,
#  'ped não': 592,
#  'entreg soment': 316,
#  'ninguém entr': 477,
#  'ninguém entr contat': 478,
#  'receb mail': 778,
#  'produt por': 680,
#  'receb produt por': 801,
#  'avali aind': 90,
#  'receb mercad': 779,
#  'receb dua': 774,
#  'one not': 554,
#  'fiscal const': 348,
#  'qual péss': 721,
#  'one not fiscal': 555,
#  'not fiscal const': 489,
#  'produt outr': 675,
#  'fret car': 363,
#  'avis não': 91,
#  'não ter': 534,
#  'não func': 512,
#  'solicit devoluç': 850,
#  'até moment': 86,
#  'moment tiv': 453,
#  'tiv retorn': 898,
#  'ato compr': 75,
#  'solicit devoluç produt': 851,
#  'qual produt': 720,
#  'produt com': 633,
#  'compr compr': 132,
#  'ressarc val': 818,
#  'produt total': 694,
#  'difer solicit': 228,
#  'não pret': 522,
#  'vei um': 983,
#  'produt total difer': 695,
#  'só vei': 859,
#  'quer devolv': 745,
#  'fret receb': 364,
#  'entreg correi': 286,
#  'ir correi': 391,
#  'eu compr': 332,
#  'envi mens': 321,
#  'so receb': 848,
#  'produt qual': 685,
#  'tem nad': 861,
#  'nad ver': 463,
#  'tem nad ver': 862,
#  'precis uma': 613,
#  'aguard orient': 12,
#  'orient troc': 558,
#  'entreg produt difer': 311,
#  'difer solicit aguard': 229,
#  'difer solicit aguard orient': 230,
#  'fiz compr': 351,
#  'doi produt': 247,
#  'compr doi produt': 135,
#  'falt peç': 336,
#  'produt péss': 683,
#  'péss qual': 715,
#  'quer meu': 751,
#  'produt péss qual': 684,
#  'quer meu dinh': 752,
#  'quer meu dinh volt': 753,
#  'produt pag': 676,
#  'venc praz': 987,
#  'cheg aind': 112,
#  'lent contat': 408,
#  'produt retorn': 689,
#  'consig entr': 171,
#  'entr em': 270,
#  'vei defeit': 968,
#  'produt vei defeit': 706,
#  'dia atras': 206,
#  'aguard retorn': 17,
#  'retorn loj': 820,
#  'as loj': 65,
#  'segund vez': 827,
#  'mesm produt': 436,
#  'produt não receb': 672,
#  'fret tiv': 365,
#  'retir correi': 819,
#  'tres jour': 907,
#  'bem inferi': 95,
#  'vei soment': 980,
#  'fiq bem': 346,
#  'entreg ped': 307,
#  'dentr praz': 192,
#  'ja solicit': 395,
#  'loj americ': 409,
#  'ja pass': 392,
#  'ja pass praz': 393,
#  'ja pass praz entreg': 394,
#  'dia praz': 210,
#  'mand mail': 422,
#  'do praz': 240,
#  'não cheg produt': 497,
#  'defeit func': 189,
#  'vei defeit func': 969,
#  'ped produt': 594,
#  'produt vei outr': 710,
#  'faz devoluç': 343,
#  'jog cam': 396,
#  'falt respeit': 338,
#  'ond produt': 542,
#  'difer compr': 220,
#  'compr model': 146,
#  'cas que': 110,
#  'que compr': 731,
#  'hundred and': 376,
#  'and night': 44,
#  'and sexta': 49,
#  'hundred and night': 381,
#  'hundred and sexta': 384,
#  'qu abr': 718,
#  'outr produt': 564,
#  'entreg se': 315,
#  'dev ter': 200,
#  'ter compr': 875,
#  'dia ten': 213,
#  'eighteen até': 256,
#  'and eighteen até': 36,
#  'thousand and eighteen até': 880,
#  'qual ruim': 723,
#  'val preç': 959,
#  'uma empr': 943,
#  'produt um': 697,
#  'tirt dia': 891,
#  'apes est': 62,
#  'doi dia': 243,
#  'ter sid': 877,
#  'mal embal': 419,
#  'receb que': 803,
#  'hoj dia': 372,
#  'dia one': 209,
#  'diss não': 235,
#  'assim não': 68,
#  'não entorn': 507,
#  'quer devoluç': 744,
#  'que ped': 737,
#  'difer que ped': 227,
#  'ped troc': 595,
#  'quas mê': 725,
#  'respeit consum': 816,
#  'falt respeit consum': 340,
#  'vei caix': 963,
#  'na caix': 459,
#  'muit satisfeit': 455,
#  'mand produt': 426,
#  'soment one': 855,
#  'quer outr': 754,
#  'fiscal vei': 350,
#  'nom outr': 486,
#  'outr pesso': 563,
#  'consig contat': 170,
#  'not fiscal vei': 491,
#  'nom outr pesso': 487,
#  'não consig contat': 502,
#  'pag produt': 575,
#  'cheg nad': 121,
#  'não cheg nad': 496,
#  'produt const': 637,
#  'entreg não': 303,
#  'minh cas': 445,
#  'devolv produt': 204,
#  'aind tiv': 31,
#  'compr tit': 158,
#  'produt foi entreg': 658,
#  'eu receb': 333,
#  'que ir': 735,
#  'ir busc': 390,
#  'entreg minh': 297,
#  'est dand': 330,
#  'entreg minh cas': 298,
#  'além não': 33,
#  'tento tiv': 873,
#  'tiv dia': 893,
#  'esper produt': 326,
#  'dinh de': 231,
#  'dinh de volt': 232,
#  'esper receb': 327,
#  'difer que compr': 226,
#  'receb produt compr': 795,
#  'mand outr': 424,
#  'relógi vei': 813,
#  'não gost': 513,
#  'outr model': 562,
#  'pag tão': 576,
#  'pag tão unidad': 577,
#  'cheg outr': 123,
#  'quer faz': 750,
#  'contat loj': 177,
#  'os correi': 559,
#  'muit decepcion': 454,
#  'entr contat loj': 269,
#  'só entreg': 857,
#  'olá boa': 540,
#  'produt cor': 638,
#  'recom loj': 810,
#  'boa noit receb': 97,
#  'receb compr': 769,
#  'tão doi': 919,
#  'and tent': 50,
#  'hundred and tent': 385,
#  'receb ped': 790,
#  'aind não receb': 25,
#  'est aguard': 329,
#  'tão hundred': 921,
#  'and twentyv': 53,
#  'and tento': 51,
#  'tão hundred and': 922,
#  'one hundred and': 547,
#  'hundred and tento': 386,
#  'tão hundred and twentyv': 923,
#  'one hundred and tento': 550,
#  'on thousand': 541,
#  'and jour': 43,
#  'compr vit lannist': 166,
#  'gost uma': 370,
#  'uma pos': 944,
#  'desd dia': 194,
#  'cheg até': 116,
#  'hoj nad': 373,
#  'até hoj nad': 84,
#  'cor azul': 180,
#  'compr dua unidad': 137,
#  'tine night': 888,
#  'night aind': 468,
#  'no aguard': 481,
#  'uma respost': 945,
#  'produt conform': 636,
#  'tud cert': 916,
#  'aind aguard': 20,
#  'não com': 498,
#  'ped tão': 596,
#  'do produt': 241,
#  'vei av': 962,
#  'tent devolv': 864,
#  'meu ped': 440,
#  'ped muit': 591,
#  'loj com': 410,
#  'compr produt vei': 155,
#  'receb outr': 788,
#  'ped doi': 588,
#  'doi tem': 248,
#  'falt respeit client': 339,
#  'cheg soment': 125,
#  'receb vei': 808,
#  'contat comig': 175,
#  'reclam não': 809,
#  'aguard pos': 13,
#  'disponibil produt': 234,
#  'inform sobr': 389,
#  'envi mail': 320,
#  'obtiv retorn': 539,
#  'nunc compr': 494,
#  'tinh produt': 889,
#  'da loj': 184,
#  'quer cancel': 743,
#  'deu cert': 197,
#  'solicit troc produt': 853,
#  'caix lent': 104,
#  'gost sab': 369,
#  'sab vai': 825,
#  'vai fic': 954,
#  'poi produt': 602,
#  'qual não': 719,
#  'tive eighteen': 899,
#  'tiv nenhum': 896,
#  'nenhum retorn': 465,
#  'entreg est': 291,
#  'mand outr produt': 425,
#  'quant tão': 724,
#  'porém receb': 605,
#  'aind foi': 22,
#  'produt aind foi': 625,
#  'aind foi entreg': 23,
#  'produt aind foi entreg': 626,
#  'troc outr': 910,
#  'gost devolv': 367,
#  'receb dinh': 772,
#  'receb dinh volt': 773,
#  'até dia': 82,
#  'dia tirte': 218,
#  'produt falt': 656,
#  'sim hundred': 837,
#  'sim hundred and': 838,
#  'sim hundred and sexta': 839,
#  'receb caix': 768,
#  'sab porqu': 822,
#  'previs entreg': 617,
#  'tento tres': 874,
#  'previs entreg dia': 618,
#  'dia tento tres': 216,
#  'entreg dia tento tres': 289,
#  'poi compr': 600,
#  'doi jog': 244,
#  'vei apen': 961,
#  'falt produt': 337,
#  'agor ninguém': 5,
#  'até agor ninguém': 79,
#  'empr entreg': 263,
#  'realiz dia': 761,
#  'compr lannist': 142,
#  'sempr compr lannist': 829,
#  'cheg não': 122,
#  'produt mand': 662,
#  'entreg não receb': 304,
#  'and fifteen': 38,
#  'one unidad': 557,
#  'dev ser': 199,
#  'cheg dat': 117,
#  'dat prev': 185,
#  'cheg dat prev': 118,
#  'produt dia': 643,
#  'nenhum satisf': 466,
#  'até agor receb': 80,
#  'cheg minh': 120,
#  'dest vez': 196,
#  'bom dia gost': 103,
#  'tão oit': 929,
#  'entreg tão': 318,
#  'contat vend': 179,
#  'pag prim': 573,
#  'prim parcel': 619,
#  'pag prim parcel': 574,
#  'compr feit': 138,
#  'nad entreg': 462,
#  'boa tard': 98,
#  'atras entreg': 76,
#  'quer receb': 756,
#  'entreg receb': 314,
#  'entreg lug': 294,
#  'lug err': 415,
#  'dor cabeç': 249,
#  'entreg lug err': 295,
#  'vend produt': 988,
#  'val cart': 956,
#  'cancel ped': 106,
#  'tre unidad': 906,
#  'entreg one': 305,
#  'pens ser': 598,
#  'não sei': 533,
#  'vei pag': 975,
#  'pag vist': 578,
#  'compr trê': 161,
#  'trê unidad': 915,
#  'diz foi': 237,
#  'fiz reclam': 353,
#  'jour dia': 397,
#  'diz foi entreg': 238,
#  'receb aguard': 763,
#  'envi outr': 322,
#  'produt eu': 653,
#  'receb não': 786,
#  'não inform': 516,
#  'que envi': 732,
#  'entreg moment': 299,
#  'compr cheg': 131,
#  'so cheg': 846,
#  'abr estal': 0,
#  'produt bom': 631,
#  'entreg mercad': 296,
#  'mand tão hundred': 428,
#  'mand tão hundred and': 429,
#  'entreg tento': 317,
#  'night até': 469,
#  'agor receb produt': 8,
#  'and forte': 41,
#  'hundred and forte': 379,
#  'const entreg': 173,
#  'nunc acontec': 493,
#  'ped complet': 587,
#  'impress há': 387,
#  'produt praz': 682,
#  'receb produt praz': 802,
#  'eighteen até moment': 258,
#  'até moment nad': 87,
#  'produt uma': 700,
#  'fiq satisfeit': 347,
#  'entreg feit': 292,
#  'do receb': 242,
#  'lannister com': 407,
#  'one mê': 553,
#  'vei produt': 976,
#  'produt anunci': 627,
#  'compr loj': 143,
#  'vez receb': 993,
#  'compr loj lannist': 144,
#  'troc produt poi': 913,
#  'quebr quer': 742,
#  'produt vei quebr': 711,
#  'produt complet': 634,
#  'falt jour': 334,
#  'receb produt complet': 794,
#  'vei corret': 967,
#  'qual recom': 722,
#  'vit st': 995,
#  'unidad sra': 953,
#  'quebr não': 741,
#  'não der': 505,
#  'cheg dia': 119,
#  'tento jour': 868,
#  'forte night': 361,
#  'night hor': 470,
#  'dia tento jour': 215,
#  'eighteen até agor': 257,
#  'forte night hor': 362,
#  'and eighteen até agor': 37,
#  'tin hundred': 885,
#  'and fitá': 40,
#  'and one': 45,
#  'and setenta': 46,
#  'setenta on': 835,
#  'tin hundred and': 886,
#  'hundred and fitá': 378,
#  'hundred and setenta': 382,
#  'and setenta on': 47,
#  'hundred and setenta on': 383,
#  'não poss': 520,
#  'thousand one': 881,
#  'agor cheg': 3,
#  'troc poi': 911,
#  'produt só': 692,
#  'produt corret': 640,
#  'boa tard receb': 100,
#  'não que': 524,
#  'receb not': 784,
#  'faz de': 342,
#  'apen one unidad': 58,
#  'receb apen one unidad': 767,
#  'and fit': 39,
#  'hundred and fit': 377,
#  'one hundred and fit': 548,
#  'dia teve': 217,
#  'não produt': 523,
#  'produt me': 663,
#  'produt me entreg': 664,
#  'entreg apen one': 278,
#  'ter receb': 876,
#  'não indic': 515,
#  'dia compr': 207,
#  'bom dia compr': 102,
#  'empr targaryen': 264,
#  'vend produt não': 990,
#  'quas tão': 728,
#  'tão mes': 925,
#  'quas tão mes': 729,
#  'receb tão': 807,
#  'soluç problem': 854,
#  'foi feit': 357,
#  'até moment receb': 88,
#  'produt correspond': 639,
#  'produt tão': 696,
#  'produt one': 673,
#  'dem entreg': 191,
#  'ped entreg': 589,
#  'devolv dinh': 203,
#  'receb outr produt': 789,
#  'tem compr': 860,
#  'agor não': 6,
#  'vez não': 992,
#  'abr reclam': 1,
#  'aguard reembols': 15,
#  'má qual': 457,
#  'apresent vit': 63,
#  'quas tent': 726,
#  'quas tent dia': 727,
#  'nenhum telefon': 467,
#  'tão night': 926,
#  'na verdad': 460,
#  'produt vei conform': 704,
#  'conform compr': 168,
#  'hoj receb': 374,
#  'contat não': 178,
#  'não tiv': 535,
#  'recomend loj': 811,
#  'que vai': 740,
#  'receb praz': 791,
#  'aguard produt': 14,
#  'emit not': 261,
#  'emit not fiscal': 262,
#  'produt muit': 667,
#  'and gineta': 42,
#  'hundred and gineta': 380,
#  'cheg atras': 115,
#  'produt ser': 690,
#  'dia entreg': 208,
#  'dia sim': 211,
#  'sim sim': 841,
#  'dia sim sim': 212,
#  'no dia': 484,
#  'produt us': 701,
#  'devoluç dinh': 201,
#  'encaix corret': 265,
#  'luminár só': 416,
#  'consegu entr': 169,
#  'ser hundred': 834,
#  'receb not fiscal': 785,
#  'cancel produt': 107,
#  'produt agor': 621,
#  'produt nem': 668,
#  'receb produt nem': 799,
#  'entreg até': 283,
#  'night thousand': 473,
#  'eighteen receb': 259,
#  'entreg até dia': 284,
#  'night thousand and': 474,
#  'night thousand and eighteen': 475,
#  'aind tinh': 30,
#  'aguard soluç': 18,
#  'sim night': 840,
#  'compr nest': 147,
#  'troc aguard': 908,
#  'compr poi': 151,
#  'produt já': 661,
#  'pret vei': 616,
#  'porém vei': 606,
#  'tão vez': 938,
#  'aguard contat': 11,
#  'compr tiv': 159,
#  'compr cancel': 130,
#  'produt dess': 642,
#  'tento tine': 872,
#  'ser entreg dia': 832,
#  'moment receb produt': 452,
#  'as loj lannist': 66,
#  'par ser': 580,
#  'tento night': 869,
#  'aind produt': 27,
#  'as lannist': 64,
#  'tiv hundred': 894,
#  'moment não': 450,
#  'entreg as': 280,
#  'diz produt': 239,
#  'mais um': 417,
#  'mais um mê': 418,
#  'quer sab que': 758,
#  'péss loj': 714,
#  'loj vend': 414,
#  'ped foi': 590,
#  'produt aguard': 622,
#  'agênc correi': 19,
#  'ped one': 593,
#  'que faz': 733,
#  'apen not': 55,
#  'apen not fiscal': 56,
#  'produt fals': 654,
#  'vou receb': 997,
#  'receb soment one': 805,
#  'tre hundred': 903,
#  'tão cartuch': 917,
#  'que pag': 736,
#  'vei quant': 977,
#  'não cumpr': 504,
#  'ate agor não': 72,
#  'além produt': 34,
#  'cumpr praz': 183,
#  'que produt': 738,
#  'loj poi': 413,
#  'assim entreg': 67,
#  'entreg foi': 293,
#  'boa tard produt': 99,
#  'entr ped': 271,
#  'se pass': 826,
#  'foi receb': 359,
#  'eighteen aind': 255,
#  'foi produt': 358,
#  'produt receb outr': 688,
#  'não gost produt': 514,
#  'produt vei caix': 703,
#  'no anúnci': 482,
#  'entreg porém': 308,
#  'tinh sid': 890,
#  'produt entreg porém': 648,
#  'ate moment': 74,
#  'praz porém': 611,
#  'produt ent': 646,
#  'produt estoqu': 652,
#  'não envi': 509,
#  'foi entreg quer': 355,
#  'outr compr': 560,
#  'um códig': 939,
#  'vem outr': 984,
#  'outr total': 565,
#  'produt um códig': 698,
#  'um códig vem': 940,
#  'vem outr total': 985,
#  'outr total difer': 566,
#  'produt um códig vem': 699,
#  'um códig vem outr': 941,
#  'vem outr total difer': 986,
#  'vo mand': 996,
#  'entreg atras': 282,
#  'and sext': 48,
#  'night hundred': 471,
#  'entreg const': 285,
#  'const vit': 174,
#  'night hundred and': 472,
#  'cap colchã': 108,
#  'entreg aguard': 272,
#  'tão night thousand': 927,
#  'tão night thousand and': 928,
#  'receb encomend': 775,
#  'one hundred and tent': 549,
#  'compr produt receb': 153,
#  'compr produt receb outr': 154,
#  'divers vez': 236,
#  'million tão': 442,
#  'million tão hundred': 443,
#  'million tão hundred and': 444,
#  'quer devolv produt': 746,
#  'papel pared': 579,
#  'receb difer': 771,
#  'poi produt vei': 603,
#  'ric se': 821,
#  'difer ped': 223,
#  'tiv hundred and': 895,
#  'jour hundred': 399,
#  'tin thousand': 887,
#  'thousand tre': 882,
#  'jour hundred and': 400,
#  'thousand tre hundred': 883,
#  'tre hundred and': 904,
#  'thousand tre hundred and': 884,
#  'tre produt': 905,
#  'receb códig': 770,
#  'corret produt': 182,
#  'tento on': 870,
#  'fiscal produt': 349,
#  'not fiscal produt': 490,
#  'produt porém': 681,
#  'grev caminh': 371,
#  'pag doi': 567,
#  'receb produt corret': 796,
#  'entreg do': 290,
#  'uma répl': 946,
#  'aguard aind': 10,
#  'produt ter': 693,
#  'não resolv': 530,
#  'and tento seren': 52,
#  'não encaix': 506,
#  'jour eighteen': 398,
#  'receb produt não': 800,
#  'not vei': 492,
#  'entreg not': 302,
#  'péss qual não': 716,
#  'produt parec': 677,
#  'não orig': 519,
#  'não prest': 521,
#  'parec produt': 582,
#  'tão sim': 932,
#  'entreg nenhum': 301,
#  'entr contat comig': 267,
#  'tento sim': 871,
#  'assim receb': 69,
#  'lannist não': 406,
#  'dua vez': 252,
#  'vend produt fals': 989,
#  'tão fit': 920,
#  'não estoqu': 510,
#  'dua luminár': 250,
#  'não foi': 511}
